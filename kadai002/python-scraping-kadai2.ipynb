# %%
pip install requests

# %%
import requests
import pprint
from getpass import getpass

# %%
# APIキーを指定
api_key = getpass('APIキーを入力してください:')  #AIzaSyABJwqhnWoec5zMD9xxqotFceHp7ly61NM
# Out:
# APIキーを入力してください:··········

# %%
# 検索キーワードを変数search_wordに格納
search_word = input('検索する駅を入力してください:')
# Out:
# 検索する駅を入力してください:秋葉原

# %%
#入力された駅の緯度経度を取得するAPIエンドポイントURL（APIアクセス接続先）
url = 'https://maps.googleapis.com/maps/api/geocode/json'

# データを取得
response = requests.get(
    url,
    params={
        'key': api_key,         #APIキーをパラメータに追加
        'address': '秋葉原',
        'location': 'LatLng',
        'placeId': 'string',
    }
)

# %%
# レスポンスのJSONを取得
json_data = response.json()

# JSONの中身を確認
pprint.pprint(json_data)
# Out:
# {'results': [{'address_components': [{'long_name': 'Akihabara Electric Town',
#                                       'short_name': 'Akihabara Electric Town',
#                                       'types': ['colloquial_area',
#                                                 'political']},
#                                      {'long_name': 'Tokyo',
#                                       'short_name': 'Tokyo',
#                                       'types': ['administrative_area_level_1',
#                                                 'political']},
#                                      {'long_name': 'Japan',
#                                       'short_name': 'JP',
#                                       'types': ['country', 'political']}],
#               'formatted_address': 'Akihabara Electric Town, Tokyo, Japan',
#               'geometry': {'bounds': {'northeast': {'lat': 35.7029818,
#                                                     'lng': 139.775761},
# ...

# %%
#レストラン情報を取得するためのAPIエンドポイントURL（APIアクセス接続先）
url2 = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'
response2 = requests.get(
    url2,
    params={
    'latitude':35.6996473,
    'longitude':139.7713703,
    'radius':500,
    'type':'restaurant',
    'key':'AIzaSyABJwqhnWoec5zMD9xxqotFceHp7ly61NM',  #APIキーをパラメータに追加
    'language': 'ja',  #言語
    }
)

# %%
# レスポンスのJSONを取得
json_data2 = response2.json()

# JSONの中身を確認
pprint.pprint(json_data2)
# Out:
# {'html_attributions': [], 'results': [], 'status': 'INVALID_REQUEST'}

# %%
# 上記ではエラーが出るため、過去のQ&Aを参照に以下のコードを作成
import requests

url2 = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?&location=35.6996473,139.7713703&radius=500&type=restaurant&keyword=language=ja&key=AIzaSyABJwqhnWoec5zMD9xxqotFceHp7ly61NM"

payload={}
headers = {}

response2 = requests.request("GET", url2, headers=headers, data=payload)

print(response2.text)
# Out:
# {
#    "html_attributions" : [],
#    "results" :
#    [
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" :
#          {
#             "location" :
#             {
#                "lat" : 35.7004016,
#                "lng" : 139.7767825
#             },
#             "viewport" :
#             {
#                "northeast" :
#                {
#                   "lat" : 35.70178547989272,
#                   "lng" : 139.7781256798928
#                },
#                "southwest" :
#                {
#                   "lat" : 35.69908582010728,
#                   "lng" : 139.7754260201073
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Jaguar Brown 秋葉原店",
# ...

# %%
# レスポンスのJSONを取得
json_data2 = response2.json()

# JSONの中身を確認
pprint.pprint(json_data2)
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.7004016, 'lng': 139.7767825},
#                            'viewport': {'northeast': {'lat': 35.70178547989272,
#                                                       'lng': 139.7781256798928},
#                                         'southwest': {'lat': 35.69908582010728,
#                                                       'lng': 139.7754260201073}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'icon_background_color': '#FF9E67',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#               'name': 'Jaguar Brown 秋葉原店',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 960,
#                           'html_attributions': ['<a '
# ...

# %%
# 取得した情報から、「レストラン名」「評価」「住所」を表示
for result in json_data2['results']:
    re_name = result['name']
    re_rating = result['rating']
    re_address = result['vicinity']
    print(re_name,re_rating,re_address)
# Out:
# Jaguar Brown 秋葉原店 4.3 1-4-5 Kanda Izumicho, Chiyoda City
# ZEERA akihabara indian restaurant 4.5 Chiyoda City, Sotokanda, 4 Chome−4−2 HULIC&New AKIHABARA 5F
# Torietsu Grand 0 Chiyoda City, Kanda Sakumacho, 1 Chome−18 信交ビル
# Egoland 394 0 Chiyoda City, Kanda Sakumacho, 4 Chome−7-3 2F
